# %%
pip install keras
# Out:
# Requirement already satisfied: keras in c:\users\sw_7\anaconda3\lib\site-packages (2.3.1)
# Requirement already satisfied: scipy>=0.14 in c:\users\sw_7\anaconda3\lib\site-packages (from keras) (1.4.1)
# Requirement already satisfied: numpy>=1.9.1 in c:\users\sw_7\anaconda3\lib\site-packages (from keras) (1.18.1)
# Requirement already satisfied: h5py in c:\users\sw_7\anaconda3\lib\site-packages (from keras) (2.9.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in c:\users\sw_7\anaconda3\lib\site-packages (from keras) (1.1.0)
# Requirement already satisfied: pyyaml in c:\users\sw_7\anaconda3\lib\site-packages (from keras) (5.1.1)
# Requirement already satisfied: six>=1.9.0 in c:\users\sw_7\appdata\roaming\python\python37\site-packages (from keras) (1.12.0)
# Requirement already satisfied: keras-applications>=1.0.6 in c:\users\sw_7\anaconda3\lib\site-packages (from keras) (1.0.8)
# Note: you may need to restart the kernel to use updated packages.

# %%
from PIL import Image
import os, glob, sys, numpy as np
from sklearn.model_selection import train_test_split
from keras.utils import np_utils

img_dir = './train1'
categories = ['new_up_2015', 'new_down_2015']
np_classes = len(categories)

image_w = 64
image_h = 64


pixel = image_h * image_w * 3

X = []
y = []

for idx, cat in enumerate(categories):
    img_dir_detail = img_dir + "/" + cat
    files = glob.glob(img_dir_detail+"/*.png")


    for i, f in enumerate(files):
        try:
            img = Image.open(f)
            img = img.convert("RGB")
            img = img.resize((image_w, image_h))
            data = np.asarray(img)
            #Y는 0 아니면 1이니까 idx값으로 넣는다.
            X.append(data)
            y.append(idx)
            if i % 3000 == 0:
                print(cat, " : ", f)
        except:
            print(cat, str(i)+" 번째에서 에러 ")
X = np.array(X)
Y = np.array(y)


X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3)

xy = (X_train, X_test, Y_train, Y_test)
np.save("./numpy_data/binary_image_data.npy", xy)
# Out:
# new_up_2015  :  ./train1/new_up_2015\20150101.PNG
# new_down_2015  :  ./train1/new_down_2015\20150104.PNG

# %%
import numpy as np
np.version.version
# Out:
# '1.16.1'

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout
from keras.callbacks import EarlyStopping, ModelCheckpoint
import matplotlib.pyplot as plt
import keras.backend.tensorflow_backend as K
import numpy as np

X_train, X_test, y_train, y_test = np.load('./numpy_data/binary_image_data.npy')
print(X_train.shape)
print(X_train.shape[0])
print(np.bincount(y_train))
print(np.bincount(y_test))
# Out:
# (935, 64, 64, 3)
# 935
# [450 485]
# [194 207]

# %%
from tensorflow.python.client import device_lib

print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 3004178121027121856
# ]

# %%
image_w = 64
image_h = 64
X_train = X_train.astype('float32') / 255
X_test = X_test.astype('float32') / 255

model = Sequential()
model.add(Conv2D(32, (3,3), padding="same", input_shape=X_train.shape[1:], activation="relu"))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Conv2D(32, (3,3), padding="same", activation="relu"))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(64, (3,3), padding="same", activation="relu"))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3,3), padding="same", activation="relu"))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(256, activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(1, activation="sigmoid"))

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

model_dir = './model'
if not os.path.exists(model_dir):
    os.mkdir(model_dir)
model_path = model_dir + "/dog_cat_classify.model"

checkpoint = ModelCheckpoint(filepath=model_path, monitor='val_loss', verbose=1, save_best_only=True)
early_stopping = EarlyStopping(monitor='val_loss', patience=7)

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_5 (Conv2D)            (None, 64, 64, 32)        896
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 32, 32, 32)        9248
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 16, 16, 64)        18496
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 8, 8, 64)          36928
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 256)               262400
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 328,225
# Trainable params: 328,225
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(X_train, y_train, batch_size=64, epochs=100, validation_split=0.15, callbacks=[checkpoint, early_stopping])
# Out:
# Train on 794 samples, validate on 141 samples
# Epoch 1/100
# 794/794 [==============================] - 4s 5ms/step - loss: 0.7001 - accuracy: 0.4874 - val_loss: 0.6912 - val_accuracy: 0.5177
#
# Epoch 00001: val_loss improved from inf to 0.69117, saving model to ./model/dog_cat_classify.model
# Epoch 2/100
# 794/794 [==============================] - 2s 3ms/step - loss: 0.6900 - accuracy: 0.5164 - val_loss: 0.6887 - val_accuracy: 0.5177
#
# Epoch 00002: val_loss improved from 0.69117 to 0.68874, saving model to ./model/dog_cat_classify.model
# Epoch 3/100
# 794/794 [==============================] - 2s 3ms/step - loss: 0.6810 - accuracy: 0.5554 - val_loss: 0.6776 - val_accuracy: 0.5745
#
# Epoch 00003: val_loss improved from 0.68874 to 0.67763, saving model to ./model/dog_cat_classify.model
# Epoch 4/100
# 794/794 [==============================] - 2s 3ms/step - loss: 0.6770 - accuracy: 0.6008 - val_loss: 0.6773 - val_accuracy: 0.5887
#
# Epoch 00004: val_loss improved from 0.67763 to 0.67728, saving model to ./model/dog_cat_classify.model
# Epoch 5/100
# 794/794 [==============================] - 2s 3ms/step - loss: 0.6649 - accuracy: 0.6058 - val_loss: 0.6852 - val_accuracy: 0.5674
#
# Epoch 00005: val_loss did not improve from 0.67728
# Epoch 6/100
# 794/794 [==============================] - 2s 2ms/step - loss: 0.6698 - accuracy: 0.6020 - val_loss: 0.6752 - val_accuracy: 0.5887
#
# Epoch 00006: val_loss improved from 0.67728 to 0.67519, saving model to ./model/dog_cat_classify.model
# Epoch 7/100
# 794/794 [==============================] - 2s 3ms/step - loss: 0.6635 - accuracy: 0.6134 - val_loss: 0.6748 - val_accuracy: 0.5887
#
# Epoch 00007: val_loss improved from 0.67519 to 0.67477, saving model to ./model/dog_cat_classify.model
# Epoch 8/100
# 794/794 [==============================] - 2s 3ms/step - loss: 0.6596 - accuracy: 0.6146 - val_loss: 0.6791 - val_accuracy: 0.5603
#
# Epoch 00008: val_loss did not improve from 0.67477
# Epoch 9/100
# 794/794 [==============================] - 2s 2ms/step - loss: 0.6678 - accuracy: 0.6322 - val_loss: 0.6751 - val_accuracy: 0.5674
#
# Epoch 00009: val_loss did not improve from 0.67477
# Epoch 10/100
# 794/794 [==============================] - 2s 2ms/step - loss: 0.6576 - accuracy: 0.6045 - val_loss: 0.6811 - val_accuracy: 0.5674
#
# Epoch 00010: val_loss did not improve from 0.67477
# Epoch 11/100
# 794/794 [==============================] - 2s 2ms/step - loss: 0.6675 - accuracy: 0.6209 - val_loss: 0.6750 - val_accuracy: 0.5887
#
# Epoch 00011: val_loss did not improve from 0.67477
# Epoch 12/100
# 794/794 [==============================] - 2s 2ms/step - loss: 0.6620 - accuracy: 0.6335 - val_loss: 0.6766 - val_accuracy: 0.5816
#
# Epoch 00012: val_loss did not improve from 0.67477
# Epoch 13/100
# 794/794 [==============================] - 2s 2ms/step - loss: 0.6529 - accuracy: 0.6272 - val_loss: 0.6737 - val_accuracy: 0.5674
#
# Epoch 00013: val_loss improved from 0.67477 to 0.67366, saving model to ./model/dog_cat_classify.model
# Epoch 14/100
# 794/794 [==============================] - 2s 2ms/step - loss: 0.6459 - accuracy: 0.6360 - val_loss: 0.6755 - val_accuracy: 0.5674
#
# Epoch 00014: val_loss did not improve from 0.67366
# Epoch 15/100
# 794/794 [==============================] - 2s 2ms/step - loss: 0.6413 - accuracy: 0.6448 - val_loss: 0.6718 - val_accuracy: 0.6028
#
# Epoch 00015: val_loss improved from 0.67366 to 0.67184, saving model to ./model/dog_cat_classify.model
# Epoch 16/100
# 794/794 [==============================] - 2s 2ms/step - loss: 0.6335 - accuracy: 0.6297 - val_loss: 0.6732 - val_accuracy: 0.6028
#
# Epoch 00016: val_loss did not improve from 0.67184
# Epoch 17/100
# 794/794 [==============================] - 2s 2ms/step - loss: 0.6286 - accuracy: 0.6486 - val_loss: 0.6740 - val_accuracy: 0.5887
#
# Epoch 00017: val_loss did not improve from 0.67184
# Epoch 18/100
# 794/794 [==============================] - 2s 2ms/step - loss: 0.6298 - accuracy: 0.6448 - val_loss: 0.6694 - val_accuracy: 0.6099
#
# Epoch 00018: val_loss improved from 0.67184 to 0.66943, saving model to ./model/dog_cat_classify.model
# Epoch 19/100
# 794/794 [==============================] - 2s 2ms/step - loss: 0.6103 - accuracy: 0.6662 - val_loss: 0.6903 - val_accuracy: 0.5674
#
# Epoch 00019: val_loss did not improve from 0.66943
# Epoch 20/100
# 794/794 [==============================] - 2s 2ms/step - loss: 0.6306 - accuracy: 0.6385 - val_loss: 0.6708 - val_accuracy: 0.5745
#
# Epoch 00020: val_loss did not improve from 0.66943
# Epoch 21/100
# 794/794 [==============================] - 2s 2ms/step - loss: 0.5930 - accuracy: 0.6763 - val_loss: 0.6851 - val_accuracy: 0.5248
#
# Epoch 00021: val_loss did not improve from 0.66943
# Epoch 22/100
# 794/794 [==============================] - 2s 2ms/step - loss: 0.6174 - accuracy: 0.6297 - val_loss: 0.6690 - val_accuracy: 0.5319
#
# Epoch 00022: val_loss improved from 0.66943 to 0.66904, saving model to ./model/dog_cat_classify.model
# Epoch 23/100
# 794/794 [==============================] - 2s 2ms/step - loss: 0.5782 - accuracy: 0.6990 - val_loss: 0.7059 - val_accuracy: 0.5816
#
# Epoch 00023: val_loss did not improve from 0.66904
# Epoch 24/100
# 794/794 [==============================] - 2s 2ms/step - loss: 0.5658 - accuracy: 0.7040 - val_loss: 0.6773 - val_accuracy: 0.5177
#
# Epoch 00024: val_loss did not improve from 0.66904
# Epoch 25/100
# 794/794 [==============================] - 2s 2ms/step - loss: 0.5418 - accuracy: 0.7620 - val_loss: 0.7524 - val_accuracy: 0.5177
#
# Epoch 00025: val_loss did not improve from 0.66904
# Epoch 26/100
# 794/794 [==============================] - 2s 2ms/step - loss: 0.5437 - accuracy: 0.7141 - val_loss: 0.6965 - val_accuracy: 0.5319
#
# Epoch 00026: val_loss did not improve from 0.66904
# Epoch 27/100
# 794/794 [==============================] - 2s 2ms/step - loss: 0.5107 - accuracy: 0.7393 - val_loss: 0.7447 - val_accuracy: 0.5248
#
# Epoch 00027: val_loss did not improve from 0.66904
# Epoch 28/100
# 794/794 [==============================] - 2s 2ms/step - loss: 0.4865 - accuracy: 0.7746 - val_loss: 0.7485 - val_accuracy: 0.5390
#
# Epoch 00028: val_loss did not improve from 0.66904
# Epoch 29/100
# 794/794 [==============================] - 2s 2ms/step - loss: 0.4609 - accuracy: 0.7758 - val_loss: 0.7273 - val_accuracy: 0.5532
#
# Epoch 00029: val_loss did not improve from 0.66904

# %%
print("정확도 : %.3f " %(model.evaluate(X_test, y_test)[1]))
# Out:
# 401/401 [==============================] - 0s 664us/step
# 정확도 : 0.566

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['loss', 'val_loss', 'acc', 'val_acc'], loc='upper left')
plt.show()
