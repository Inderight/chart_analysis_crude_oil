# %%
pip install keras
# Out:
# Requirement already satisfied: keras in c:\users\sw_7\anaconda3\lib\site-packages (2.3.1)
# Requirement already satisfied: scipy>=0.14 in c:\users\sw_7\anaconda3\lib\site-packages (from keras) (1.4.1)
# Requirement already satisfied: numpy>=1.9.1 in c:\users\sw_7\anaconda3\lib\site-packages (from keras) (1.18.1)
# Requirement already satisfied: h5py in c:\users\sw_7\anaconda3\lib\site-packages (from keras) (2.9.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in c:\users\sw_7\anaconda3\lib\site-packages (from keras) (1.1.0)
# Requirement already satisfied: pyyaml in c:\users\sw_7\anaconda3\lib\site-packages (from keras) (5.1.1)
# Requirement already satisfied: six>=1.9.0 in c:\users\sw_7\appdata\roaming\python\python37\site-packages (from keras) (1.12.0)
# Requirement already satisfied: keras-applications>=1.0.6 in c:\users\sw_7\anaconda3\lib\site-packages (from keras) (1.0.8)
# Note: you may need to restart the kernel to use updated packages.

# %%
from PIL import Image
import os, glob, sys, numpy as np
from sklearn.model_selection import train_test_split
from keras.utils import np_utils

img_dir = './train1'
categories = ['up_2016', 'down_2016']
np_classes = len(categories)

image_w = 64
image_h = 64


pixel = image_h * image_w * 3

X = []
y = []

for idx, cat in enumerate(categories):
    img_dir_detail = img_dir + "/" + cat
    files = glob.glob(img_dir_detail+"/*.png")


    for i, f in enumerate(files):
        try:
            img = Image.open(f)
            img = img.convert("RGB")
            img = img.resize((image_w, image_h))
            data = np.asarray(img)
            #Y는 0 아니면 1이니까 idx값으로 넣는다.
            X.append(data)
            y.append(idx)
            if i % 3000 == 0:
                print(cat, " : ", f)
        except:
            print(cat, str(i)+" 번째에서 에러 ")
X = np.array(X)
Y = np.array(y)


X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3)

xy = (X_train, X_test, Y_train, Y_test)
np.save("./numpy_data/binary_image_data.npy", xy)
# Out:
# up_2016  :  ./train1/up_2016\20151230.PNG
# down_2016  :  ./train1/down_2016\20160103.PNG

# %%
import numpy as np
np.version.version
# Out:
# '1.16.1'

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout
from keras.callbacks import EarlyStopping, ModelCheckpoint
import matplotlib.pyplot as plt
import keras.backend.tensorflow_backend as K
import numpy as np

X_train, X_test, y_train, y_test = np.load('./numpy_data/binary_image_data.npy')
print(X_train.shape)
print(X_train.shape[0])
print(np.bincount(y_train))
print(np.bincount(y_test))
# Out:
# (753, 64, 64, 3)
# 753
# [388 365]
# [158 166]

# %%
from tensorflow.python.client import device_lib

print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 5727455601752772567
# ]

# %%
image_w = 64
image_h = 64
X_train = X_train.astype('float32') / 255
X_test = X_test.astype('float32') / 255

model = Sequential()
model.add(Conv2D(32, (3,3), padding="same", input_shape=X_train.shape[1:], activation="relu"))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Conv2D(32, (3,3), padding="same", activation="relu"))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(64, (3,3), padding="same", activation="relu"))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3,3), padding="same", activation="relu"))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(256, activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(1, activation="sigmoid"))

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

model_dir = './model'
if not os.path.exists(model_dir):
    os.mkdir(model_dir)
model_path = model_dir + "/dog_cat_classify.model"

checkpoint = ModelCheckpoint(filepath=model_path, monitor='val_loss', verbose=1, save_best_only=True)
early_stopping = EarlyStopping(monitor='val_loss', patience=7)

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_5 (Conv2D)            (None, 64, 64, 32)        896
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 32, 32, 32)        9248
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 16, 16, 64)        18496
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 8, 8, 64)          36928
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 256)               262400
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 328,225
# Trainable params: 328,225
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(X_train, y_train, batch_size=64, epochs=100, validation_split=0.15, callbacks=[checkpoint, early_stopping])
# Out:
# Train on 640 samples, validate on 113 samples
# Epoch 1/100
# 640/640 [==============================] - 4s 6ms/step - loss: 0.7163 - accuracy: 0.5063 - val_loss: 0.6874 - val_accuracy: 0.5487
#
# Epoch 00001: val_loss improved from inf to 0.68744, saving model to ./model/dog_cat_classify.model
# Epoch 2/100
# 640/640 [==============================] - 2s 3ms/step - loss: 0.6950 - accuracy: 0.5000 - val_loss: 0.6977 - val_accuracy: 0.4513
#
# Epoch 00002: val_loss did not improve from 0.68744
# Epoch 3/100
# 640/640 [==============================] - 2s 3ms/step - loss: 0.6877 - accuracy: 0.5672 - val_loss: 0.6949 - val_accuracy: 0.4513
#
# Epoch 00003: val_loss did not improve from 0.68744
# Epoch 4/100
# 640/640 [==============================] - 2s 3ms/step - loss: 0.6872 - accuracy: 0.5609 - val_loss: 0.6720 - val_accuracy: 0.6195
#
# Epoch 00004: val_loss improved from 0.68744 to 0.67199, saving model to ./model/dog_cat_classify.model
# Epoch 5/100
# 640/640 [==============================] - 2s 3ms/step - loss: 0.6675 - accuracy: 0.6094 - val_loss: 0.6543 - val_accuracy: 0.6283
#
# Epoch 00005: val_loss improved from 0.67199 to 0.65428, saving model to ./model/dog_cat_classify.model
# Epoch 6/100
# 640/640 [==============================] - 2s 2ms/step - loss: 0.6721 - accuracy: 0.6172 - val_loss: 0.6565 - val_accuracy: 0.6283
#
# Epoch 00006: val_loss did not improve from 0.65428
# Epoch 7/100
# 640/640 [==============================] - 2s 2ms/step - loss: 0.6673 - accuracy: 0.6328 - val_loss: 0.6461 - val_accuracy: 0.6460
#
# Epoch 00007: val_loss improved from 0.65428 to 0.64608, saving model to ./model/dog_cat_classify.model
# Epoch 8/100
# 640/640 [==============================] - 2s 3ms/step - loss: 0.6616 - accuracy: 0.6141 - val_loss: 0.6566 - val_accuracy: 0.6106
#
# Epoch 00008: val_loss did not improve from 0.64608
# Epoch 9/100
# 640/640 [==============================] - 2s 3ms/step - loss: 0.6592 - accuracy: 0.6141 - val_loss: 0.6539 - val_accuracy: 0.6283
#
# Epoch 00009: val_loss did not improve from 0.64608
# Epoch 10/100
# 640/640 [==============================] - 2s 3ms/step - loss: 0.6527 - accuracy: 0.6172 - val_loss: 0.6461 - val_accuracy: 0.6460
#
# Epoch 00010: val_loss did not improve from 0.64608
# Epoch 11/100
# 640/640 [==============================] - 2s 2ms/step - loss: 0.6519 - accuracy: 0.6344 - val_loss: 0.6554 - val_accuracy: 0.6195
#
# Epoch 00011: val_loss did not improve from 0.64608
# Epoch 12/100
# 640/640 [==============================] - 2s 2ms/step - loss: 0.6515 - accuracy: 0.6375 - val_loss: 0.6496 - val_accuracy: 0.6106
#
# Epoch 00012: val_loss did not improve from 0.64608
# Epoch 13/100
# 640/640 [==============================] - 2s 2ms/step - loss: 0.6435 - accuracy: 0.6266 - val_loss: 0.6553 - val_accuracy: 0.6106
#
# Epoch 00013: val_loss did not improve from 0.64608
# Epoch 14/100
# 640/640 [==============================] - 2s 2ms/step - loss: 0.6398 - accuracy: 0.6328 - val_loss: 0.6499 - val_accuracy: 0.6195
#
# Epoch 00014: val_loss did not improve from 0.64608

# %%
print("정확도 : %.3f " %(model.evaluate(X_test, y_test)[1]))
# Out:
# 324/324 [==============================] - 0s 1ms/step
# 정확도 : 0.596

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['loss', 'val_loss', 'acc', 'val_acc'], loc='upper left')
plt.show()
